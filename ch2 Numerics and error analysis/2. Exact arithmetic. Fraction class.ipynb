# %%
a1 = 146
a2 = 146
a1 == a2
# Out:
# True

# %%
a1 is a2
# Out:
# True

# %%
id(a1), id(a2)
# Out:
# (94409566133280, 94409566133280)

# %%
id(a1)==id(a2)
# Out:
# True

# %%
b1 = 500
b2 = 500
b1 == b2
# Out:
# True

# %%
b1 is b2
# Out:
# False

# %%
id(b1), id(b2)
# Out:
# (140197905860976, 140197905860944)

# %%
id(b1) == id(b2)
# Out:
# False

# %% [markdown]
# From 5 to 255
# Interning
#
# https://towardsdatascience.com/optimization-in-python-interning-805be5e9fd3e

# %% [markdown]
# Float errors

# %%
0.1 + 0.1  + 0.1
# Out:
# 0.30000000000000004

# %%
from decimal import Decimal

# %%
Decimal(0.1) + Decimal(0.1)  + Decimal(0.1)
# Out:
# Decimal('0.3000000000000000166533453694')

# %%
Decimal('0.1') + Decimal('0.1')  + Decimal('0.1')
# Out:
# Decimal('0.3')

# %% [markdown]
# Fractions
#
# A class representing rational numbers. An instance of the class can be created from a pair of numbers (numerator, denominator), from another rational number, from a floating point number, from a number of type decimal.Decimal, and from a string representing a number.

# %%
from fractions import Fraction

# %%
Fraction(1, 3)
# Out:
# Fraction(1, 3)

# %%
Fraction(100)
# Out:
# Fraction(100, 1)

# %%
Fraction()
# Out:
# Fraction(0, 1)

# %%
Fraction('3/7')
# Out:
# Fraction(3, 7)

# %%
Fraction(' 3/7 ')
# Out:
# Fraction(3, 7)

# %%
Fraction('3.1415')
# Out:
# Fraction(6283, 2000)

# %%
Fraction(3.1415)
# Out:
# Fraction(7074029114692207, 2251799813685248)

# %%
a = Fraction(1, 7)
b = Fraction(1, 3)

# %%
a + b
# Out:
# Fraction(10, 21)

# %%
a - b
# Out:
# Fraction(-4, 21)

# %%
a * b
# Out:
# Fraction(1, 21)

# %%
a / b
# Out:
# Fraction(3, 7)

# %%
a % b
# Out:
# Fraction(1, 7)

# %%
c = b % a
c, type(c)
# Out:
# (Fraction(1, 21), fractions.Fraction)

# %%
c = a ** b
c, type(c)
# Out:
# (0.5227579585747102, float)

# %%
abs(a - b)
# Out:
# Fraction(4, 21)

# %%
a = Fraction(3.1415)
a
# Out:
# Fraction(7074029114692207, 2251799813685248)

# %%
7074029114692207 / 2251799813685248
# Out:
# 3.1415

# %%
from fractions import gcd
gcd(7074029114692207, 2251799813685248)
# Out:
# 1

# %%
a.limit_denominator()
# Out:
# Fraction(6283, 2000)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
gcd(1, 5)
# Out:
# 1

# %%
gcd(1000, 3)
# Out:
# 1

# %%
gcd(4, 6)
# Out:
# 2

# %%
gcd(0, 2)
# Out:
# 2

# %%
gcd(0, 0)
# Out:
# 0
