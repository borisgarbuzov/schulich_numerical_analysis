# %%
import numpy as np
import scipy
from scipy import linalg

# %% [markdown]
# # Full design, not implemented
#
# Take tall random matrix A of size 2n by n
#
# Multiply С = (A.T)@A
#
# Expand P, L, U = lu(C), measuring time
#
# Expand L = cholesky(C), measuring time
#
# Run in a cycle from 1к to 100к by 1к
#
# Plot time dependence on size
#
# # Simplified check:

# %%
# np.random.rand(8,4, type=np.uint8)
# np.random.randint(9, size=(8, 4))

# %%
A = scipy.array([[8, 0, 6, 2],
                [6, 3, 8, 3],
                [4, 7, 3, 4],
                [7, 3, 6, 0],
                [2, 8, 2, 8],
                [5, 1, 4, 2],
                [3, 1, 0, 0],
                [0, 3, 0, 4]])
A
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: scipy.array is deprecated and will be removed in SciPy 2.0.0, use numpy.array instead
# array([[8, 0, 6, 2],
#        [6, 3, 8, 3],
#        [4, 7, 3, 4],
#        [7, 3, 6, 0],
#        [2, 8, 2, 8],
#        [5, 1, 4, 2],
#        [3, 1, 0, 0],
#        [0, 3, 0, 4]])

# %%
C = (A.T) @ A
C
# Out:
# array([[203,  91, 174,  76],
#        [ 91, 142,  83, 115],
#        [174,  83, 165,  72],
#        [ 76, 115,  72, 113]])

# %%
# %%timeit
P, L, U = linalg.lu(A)
# Out:
# The slowest run took 17.10 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100000 loops, best of 5: 14.3 µs per loop

# %%
# %%timeit
L = scipy.linalg.cholesky(C, lower=True)
# Out:
# The slowest run took 28.69 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100000 loops, best of 5: 6.1 µs per loop

# %%
# %%timeit
U = scipy.linalg.cholesky(C, lower=False)
# Out:
# The slowest run took 18.31 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100000 loops, best of 5: 6.4 µs per loop
