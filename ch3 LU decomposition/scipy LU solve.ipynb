# %%
import numpy as np
import scipy.linalg as la

# %%
A = np.array([[2,4],[3,5]])
A
# Out:
# array([[2, 4],
#        [3, 5]])

# %%
b = np.array([2,4])
#.reshape((-1,1))
b
# Out:
# array([2, 4])

# %%
x = la.solve(A, b)
x
# Out:
# array([ 3., -1.])

# %% [markdown]
# <a href="http://people.duke.edu/~ccc14/sta-663-2018/notebooks/S08B_Sovling_Linear_Equations_Annotated.html">More examples</a>

# %%
P, L, U = la.lu(A)
P
# Out:
# array([[0., 1.],
#        [1., 0.]])

# %%
L
# Out:
# array([[1.        , 0.        ],
#        [0.66666667, 1.        ]])

# %%
U
# Out:
# array([[3.        , 5.        ],
#        [0.        , 0.66666667]])
