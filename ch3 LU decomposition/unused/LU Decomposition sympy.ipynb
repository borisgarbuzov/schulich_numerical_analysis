# %%
from sympy import Matrix

# %%
A = Matrix ([[1, 2, 3], [4, 5, 6], [10, 11, 12]])
A
# Out:
# ⎡1   2   3 ⎤
# ⎢          ⎥
# ⎢4   5   6 ⎥
# ⎢          ⎥
# ⎣10  11  12⎦

# %%
from sympy import init_printing
init_printing()

# %%
A
# Out:
# ⎡1   2   3 ⎤
# ⎢          ⎥
# ⎢4   5   6 ⎥
# ⎢          ⎥
# ⎣10  11  12⎦

# %%
L, U, _ = A.LUdecomposition()

# %%
U
# Out:
# ⎡1  2   3 ⎤
# ⎢         ⎥
# ⎢0  -3  -6⎥
# ⎢         ⎥
# ⎣0  0   0 ⎦

# %%
L
# Out:
# ⎡1   0  0⎤
# ⎢        ⎥
# ⎢4   1  0⎥
# ⎢        ⎥
# ⎣10  3  1⎦

# %%
L * U
# Out:
# ⎡1   2   3 ⎤
# ⎢          ⎥
# ⎢4   5   6 ⎥
# ⎢          ⎥
# ⎣10  11  12⎦

# %%
U * L
# Out:
# ⎡39   11   3 ⎤
# ⎢            ⎥
# ⎢-72  -21  -6⎥
# ⎢            ⎥
# ⎣ 0    0   0 ⎦

# %%
L @ U
# Out:
# ⎡1   2   3 ⎤
# ⎢          ⎥
# ⎢4   5   6 ⎥
# ⎢          ⎥
# ⎣10  11  12⎦

# %%
A == L @ U
# Out:
# True

# %%
A2 = Matrix ([[2, 4], [3, 5]])
A2
# Out:
# ⎡2  4⎤
# ⎢    ⎥
# ⎣3  5⎦

# %%
L2, U2, _ = A2.LUdecomposition()
L2
# Out:
# ⎡ 1   0⎤
# ⎢      ⎥
# ⎣3/2  1⎦

# %%
U2
# Out:
# ⎡2  4 ⎤
# ⎢     ⎥
# ⎣0  -1⎦

# %%
L2a = Matrix ([[2, 0], [3, -1]])
L2a
# Out:
# ⎡2  0 ⎤
# ⎢     ⎥
# ⎣3  -1⎦

# %%
U2a = Matrix ([[1, 2], [0, 1]])
U2a
# Out:
# ⎡1  2⎤
# ⎢    ⎥
# ⎣0  1⎦

# %%
A2a = L2a @ U2a
A2a
# Out:
# ⎡2  4⎤
# ⎢    ⎥
# ⎣3  5⎦

# %%
A2a == A2
# Out:
# True

# %%
A2.inv()
# Out:
# ⎡-5/2  2 ⎤
# ⎢        ⎥
# ⎣3/2   -1⎦
