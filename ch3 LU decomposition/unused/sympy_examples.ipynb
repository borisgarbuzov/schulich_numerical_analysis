# %%
from sympy.matrices import Matrix, eye

# %%
A = eye(2)*2
B = Matrix([[1, 2], [3, 4]])
A.LDLsolve(B) == B/2
# Out:
# True

# %%
A
# Out:
# Matrix([
# [2, 0],
# [0, 2]])

# %%
B
# Out:
# Matrix([
# [1, 2],
# [3, 4]])

# %%
a = Matrix([[4, 3], [6, 3]])
L, U, perms = a.LUdecomposition()

# %%
L
# Out:
# Matrix([
# [  1, 0],
# [3/2, 1]])

# %%
U
# Out:
# Matrix([
# [4,    3],
# [0, -3/2]])

# %%
perms
# Out:
# []

# %%
P = eye(a.rows).permuteFwd(perms)
P
# Out:
# Matrix([
# [1, 0],
# [0, 1]])

# %%
a = Matrix([[0, 2, 3], [3,2,1], [1, 2, 3]])
L, U, perms = a.LUdecomposition()

# %%
perms
# Out:
# [[0, 1]]

# %%
A = Matrix([[1,2,3],[4,5,6]])
L, U, perm = A.LUdecomposition()
perm
# Out:
# []
