# %%
import numpy as np
# from mpl_toolkits.mplot3d import Axes3D  
# Axes3D import has side effects, it enables using projection='3d' in add_subplot
import matplotlib.pyplot as plt
import random

def fun(x, y):
    return x**2 + y
    

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x = y = np.linspace(-10, 10, 1000)
X, Y = np.meshgrid(x, y)
zs = np.array(fun(np.ravel(X), np.ravel(Y)))
Z = zs.reshape(X.shape)

ax.plot_surface(X, Y, Z)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
import plotly.graph_objects as go
import numpy as np
# Read data from a csv
x, y = np.linspace(-10, 10, 1000), np.linspace(-10, 10, 1000)
xx, yy = np.meshgrid(x, y, indexing='xy')
z = np.zeros((x.size, y.size))
for (i,j),v in np.ndenumerate(z):
    z[i,j] =(abs(max(xx[i, j], yy[i, j])))
    
zn = z+1
fig = go.Figure(data=[go.Surface(z=z), go.Surface(z=z, showscale=False, opacity=0.9)])
# fig.update_layout(title='Function figure', autosize=False,
#                   width=1000, height=750,
#                   margin=dict(l=65, r=50, b=65, t=90))
fig.show()

# %%
# from mpl_toolkits import mplot3d 
import matplotlib.pyplot as plt

# %%
x, y = np.linspace(-10, 10, 1000), np.linspace(-10, 10, 1000)
xx, yy = np.meshgrid(x, y, indexing='xy')
z = np.zeros((x.size, y.size))
for (i,j),v in np.ndenumerate(z):
    z[i,j] =(abs(max(xx[i, j], yy[i, j])))


fig = plt.figure(figsize=(20,14))
ax = fig.add_subplot(111, projection='3d')


# surf = ax.plot_surface(x,y,z, cmap=cm.coolwarm)
surf = ax.plot_wireframe(xx,yy,z)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
ax.view_init(60, 60)
fig
