# %%
list1 = [10, 20]
list2 = [1, 2, 3]
enum = enumerate(list1)
enum, list(enum),
# Out:
# (<enumerate at 0x7f84cac055a0>, [(0, 10), (1, 20)])

# %%
enum2 = enumerate(list1)
next(enum2)
# Out:
# (0, 10)

# %%
enum3 = enumerate(list1)
[x for x in enum3]
# Out:
# [(0, 10), (1, 20)]

# %%
two = [10, 20]
three = [1, 2, 3]
myLenght = len(two)* len(three)
for i in range(myLenght):
    ceilTwo = i // 2
    ceilThree = i // 3
    residueTwo = i % 2
    residueThree = i % 3
    print(i, myTwo, myThree, residueTwo, residueThree)
# Out:
# 0 2 1 0 0
# 1 2 1 1 1
# 2 2 1 0 2
# 3 2 1 1 0
# 4 2 1 0 1
# 5 2 1 1 2
