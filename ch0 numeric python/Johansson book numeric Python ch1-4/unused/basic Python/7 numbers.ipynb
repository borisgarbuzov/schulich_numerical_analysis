# %%
var1 = 1
var2 = 0x10
var3 = 12e5
var4 = 0o420
print("var2 =", var2)
print("var3 =", var3)
print("var4 =", var4)
0 * 8 ** 0 + 2 * 8 ** 1  + 4 * 8 ** 2
# Out:
# var2 = 16
# var3 = 1200000.0
# var4 = 272
# 272

# %%
del var1, var2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-997d84dc1113> in <module>()
# ----> 1 del var1, var2
#
# NameError: name 'var1' is not defined

# %%
z = 1
print(z)
z = float(z)
print(z)
z = complex(z)
print(z)
z = int(z)
print(z)
# Out:
# 1
# 1.0
# (1+0j)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-7cfc799e91f7> in <module>()
#       5 z = complex(z)
#       6 print(z)
# ----> 7 z = int(z)
#       8 print(z)
#
# TypeError: can't convert complex to int

# %%
my_complex = 2+3j
int(my_complex)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-a6b1040e8f79> in <module>()
#       1 my_complex = 2+3j
# ----> 2 int(my_complex)
#
# TypeError: can't convert complex to int

# %%
2+3j
# Out:
# (2+3j)
