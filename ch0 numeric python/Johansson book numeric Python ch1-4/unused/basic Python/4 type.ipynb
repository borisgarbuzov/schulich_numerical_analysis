# %%
a = 300  
a
# Out:
# 300

# %%
# pipe assignment
a = b = c = 300  

# collective printing
print(a, b, c)
# Out:
# 300 300 300

# %%
# type change
var = 23.5
print(var)
var = "Now I'm a string"
print(var)
# Out:
# 23.5
# Now I'm a string

# %%
# printing not assigned value
print(300)
# Out:
# 300

# %%
# first assignment
n = 300

# %%
# chain assignment
m = n

# %%
# reassignment
m = 400
# n is still the same
n
# Out:
# 300

# %%
# another reassignment
n = "foo"
# At this point, constant 400 is orphaned, not referred by any variable

# %%
# Exists, but we will not use declarations
x = int()   # "x" declared as integer
x = True
x = "abc"

# %%
int(2.5)
# Out:
# 2
