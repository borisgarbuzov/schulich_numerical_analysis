# %%
var1 = 100
if var1:
   print ("1 - Got a true expression value")
   print (var1)
# Out:
# 1 - Got a true expression value
# 100

# %%
var1 = 100 

if var1: 

print ("1 - Got a true expression value") 

print (var1)
# Out:
#   File "<ipython-input-2-027d821a90da>", line 5
#     print ("1 - Got a true expression value")
#         ^
# IndentationError: expected an indented block

# %%
amount = int(input("Enter amount: "))

if amount<1000:
   discount = amount*0.05
   print ("Discount",discount)
else:
   discount = amount*0.10
   print ("Discount",discount)
    
print ("Net payable:",amount-discount)
# Out:
# Enter amount: 3
# Discount 0.15000000000000002
# Net payable: 2.85

# %%
amount = int(input("Enter amount: "))
# amount = 5
if amount<1000:
   discount = amount*0.05
   print ("Discount",discount)
elif amount<5000:
   discount = amount*0.10
   print ("Discount",discount)
else:
   discount = amount*0.15
   print ("Discount",discount)
    
print ("Net payable:",amount-discount)
# Out:
# Enter amount: 50000
# Discount 7500.0
# Net payable: 42500.0

# %%
amount = int(input("Enter amount: "))
if amount<1000:
    discount = amount*0.05
    print ("Discount",discount)
else:
    if amount<5000:
        discount = amount*0.10
        print ("Discount",discount)
    else:
        discount = amount*0.15
        print ("Discount",discount)
        print ("Net payable:",amount-discount)
# Out:
# Enter amount: 7
# Discount 0.35000000000000003
