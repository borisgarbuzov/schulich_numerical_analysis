# %%
print("Hello Data Science")
# Out:
# Hello Data Science

# %% [markdown]
# Below is the syntax error due to wrong indentation

# %%
if True: 

print("True") 

else: 

print("False")
# Out:
#   File "<ipython-input-7-9296166ec85e>", line 3
#     print("True")
#         ^
# IndentationError: expected an indented block

# %%
if True:
	print("True")
else:
	print("False")
# Out:
# True

# %% [markdown]
# Multi-line sting

# %%
word = 'word'
sentence = "This is a sentence."
paragraph = """This is a paragraph. It is
made up of multiple lines and sentences."""

print(word)
print(sentence)
print(paragraph)
# Out:
# word
# This is a sentence.
# This is a paragraph. It is
# made up of multiple lines and sentences.

# %%
# First comment
print("Hello, Python!") # second comment

# %%
" this is my single line comment"

'''  

This is a multiline  


comment.  

'''
