# %%
tup1 = ('physics', 'chemistry', 1997, 2000)
tup2 = (1, 2, 3, 4, 5 )
tup3 = "a", "b", "c", "d"

print(tup1, tup2, tup3)
# Out:
# ('physics', 'chemistry', 1997, 2000) (1, 2, 3, 4, 5) ('a', 'b', 'c', 'd')

# %%
print ("tup1[0]: ", tup1[0])
print ("tup2[1:5]: ", tup2[1:5])
# Out:
# tup1[0]:  physics
# tup2[1:5]:  (2, 3, 4, 5)

# %%
x = ("apple", "banana", "cherry")
y = list(x)
y[1] = "kiwi"
x = tuple(y)
print(x)
# Out:
# ('apple', 'kiwi', 'cherry')

# %%
tup1 = (12, 34.56)
tup2 = ('abc', 'xyz')
tup3 = tup1 + tup2
print (tup3)
# Out:
# (12, 34.56, 'abc', 'xyz')

# %%
tup1 = (12, 34.56)
tup2 = (13, 34.56)
print(min(tup1,tup2))
# Out:
# (12, 34.56)

# %%
tup1 = (12, 34.56, 'a')
print(tup1.index('a'))
# Out:
# 2

# %%
x = ("apple", "banana", "cherry")
x[1] = "kiwi"
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-57dfcae579d5> in <module>()
#       1 x = ("apple", "banana", "cherry")
# ----> 2 x[1] = "kiwi"
#       3 print(x)
#
# TypeError: 'tuple' object does not support item assignment
