# %%
print("Hello")
print('Hello')
# Out:
# Hello
# Hello

# %%
var1 = 'Hello World!'
var2 = "Python Programming"
print ("var1[0]: ", var1[0])
print ("var2[1:5]: ", var2[1:5])
# Out:
# var1[0]:  H
# var2[1:5]:  ytho

# %%
var1 = 'Hello World!'
var1 += "~"
print(var1)

var1[1] = 'o'
# Out:
# Hello World!~
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-082a86d8316f> in <module>()
#       3 print(var1)
#       4
# ----> 5 var1[1] = 'o'
#
# TypeError: 'str' object does not support item assignment

# %%
b = "Hello, World!"
print(b[2:5])
# Out:
# llo

# %%
print(b[-5:-2])
emptyString = b[-2:-5]
print(emptyString)
print(type(emptyString))
print(len(emptyString))
# dir(emptyString)
# Out:
# orl
#
# <class 'str'>
# 0

# %%
# concatenation
a = "Hello"
b = "World"
c = a + " " + b
print(c)

# %%
# Transform to an upper case
txt = "Hello my friends"
x = txt.upper()
print(x)
# Out:
# HELLO MY FRIENDS

# %%
# Join a sequence, delimited by separator. 
s = "-"
seq = ("a", "b", "c") # This is sequence of strings.
print (s.join( seq ))
# Out:
# a-b-c
