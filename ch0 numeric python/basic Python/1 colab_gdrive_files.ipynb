# %%
# !ls
# !pwd
# Out:
# sample_data
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# On the left, the drive folder appears. We expand it and find colab notebooks. Then we find the dataset file of interest and copy its path
# "/content/drive/My Drive/Colab Notebooks/York/ds1/Week 2 Python intro/wordlist.txt"

# %%
myDataFile = open ("/content/drive/My Drive/Colab Notebooks/York/ds1/Week 2 Python intro/wordlist.txt", "r")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-f8c8aa0ceb98> in <module>()
#       1
# ----> 2 myDataFile = open ("/content/drive/My Drive/Colab Notebooks/York/ds1/Week 2 Python intro/wordlist.txt", "r")
#       3
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/York/ds1/Week 2 Python intro/wordlist.txt'

# %%
for i in range(1, 10):
  myLine = myDataFile.readline()
  print("line ", i, "= ", myLine.rstrip())
