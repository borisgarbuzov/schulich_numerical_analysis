# %%
import numpy as np
float_formatter = lambda x: "%.2f" % x
np.set_printoptions(formatter={'float_kind':float_formatter})

def power_iteration(A, num_simulations: int):
    # Ideally choose a random vector
    # To decrease the chance that our vector
    # Is orthogonal to the eigenvector
    b_k = (np.random.rand(A.shape[1]) - 1/2)*10
    # b_k = np.random.normal(A.shape[1])

    for iteration in range(num_simulations):
        # calculate the matrix-by-vector product Ab
        b_k1 = np.dot(A, b_k)

        # calculate the norm
        b_k1_norm = np.linalg.norm(b_k1)

        # re normalize the vector
        b_k = b_k1 / b_k1_norm
        print("iteration: ", iteration, ", b_k = ", b_k)
        numerator = b_k1 @ A @ b_k
        denominator = b_k @ b_k
        lambda_k = numerator / denominator
        print("lambda_k = ", lambda_k)
        print()
    return b_k

power_iteration(np.array([[0.5, 0.5], [0.2, 0.8]]), 10)
# Out:
# iteration:  0 , b_k =  [0.26 -0.96]
# lambda_k =  0.7993116695612582
#
# iteration:  1 , b_k =  [-0.44 -0.90]
# lambda_k =  0.8141078687750376
#
# iteration:  2 , b_k =  [-0.64 -0.77]
# lambda_k =  1.0705624377849126
#
# iteration:  3 , b_k =  [-0.69 -0.73]
# lambda_k =  1.0318729135983753
#
# iteration:  4 , b_k =  [-0.70 -0.71]
# lambda_k =  1.010274484819052
#
# iteration:  5 , b_k =  [-0.71 -0.71]
# lambda_k =  1.0031392497383709
#
# iteration:  6 , b_k =  [-0.71 -0.71]
# lambda_k =  1.0009467027119932
#
# iteration:  7 , b_k =  [-0.71 -0.71]
# lambda_k =  1.0002844491116754
#
# iteration:  8 , b_k =  [-0.71 -0.71]
# lambda_k =  1.0000853740400655
#
# iteration:  9 , b_k =  [-0.71 -0.71]
# lambda_k =  1.000025615745825
# array([-0.71, -0.71])
