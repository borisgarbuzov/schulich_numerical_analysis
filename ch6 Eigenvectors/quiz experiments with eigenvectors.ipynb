# %%
import numpy as np
a = np.array([[3, 1], [2, 2]])
w, v = np.linalg.eig(a)
print(w)
print(v)
# Out:
# [4. 1.]
# [[ 0.70710678 -0.4472136 ]
#  [ 0.70710678  0.89442719]]

# %%
np.dot(a, v) == w*v
# Out:
# array([[ True, False],
#        [ True,  True]])

# %%
w*v
# Out:
# array([[ 2.82842712, -0.4472136 ],
#        [ 2.82842712,  0.89442719]])

# %%
np.dot(a, v)
# Out:
# array([[ 2.82842712, -0.4472136 ],
#        [ 2.82842712,  0.89442719]])

# %%
np.array_equal(np.dot(a, v), (w*v))
# Out:
# False

# %%
# !!!!
np.allclose(np.dot(a, v), w*v)
# Out:
# True

# %%
np.isclose(np.dot(a, v), w*v)
# Out:
# array([[ True,  True],
#        [ True,  True]])
