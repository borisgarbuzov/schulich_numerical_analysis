# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
i = np.array([1, 0])
j = np.array([0, 1])

x = i + j


A = np.array([[2, 3], [-2, 4]])
U, s, V_t = np.linalg.svd(A)

S = np.diag(s)

US = np.dot(U, S)
USV_t = np.dot(US, V_t)
USV_t
# Out:
# array([[ 2.,  3.],
#        [-2.,  4.]])

# %%
V = np.array([i, j])
UV = np.dot(U, V)

plt.arrow(0, 0, UV[0][0], UV[0][1], color='b', label='Si', head_length=.2, head_width=.1, length_includes_head=True)
plt.arrow(0, 0, UV[1][0], UV[1][1], color='b', label='Sj', head_length=.2, head_width=.1, length_includes_head=True)
plt.arrow(0, 0, i[0], i[1], color='r', label='i', head_length=.2, head_width=.1, length_includes_head=True)
plt.arrow(0, 0, j[0], j[1], color='r', label='j', head_length=.2, head_width=.1, length_includes_head=True)

plt.title('Rotations in SVD')
plt.xlim(-3, 3)
plt.ylim(-2, 2)


plt.grid()

plt.rcParams["figure.figsize"] = (15,10)

# %%
V = np.array([i, j])
SV = np.dot(S, V)

plt.arrow(0, 0, SV[0][0], SV[0][1], color='b', label='Si', head_length=.2, head_width=.1, length_includes_head=True)
plt.arrow(0, 0, SV[1][0], SV[1][1], color='b', label='Sj', head_length=.2, head_width=.1, length_includes_head=True)
plt.arrow(0, 0, i[0], i[1], color='r', label='i', head_length=.2, head_width=.1, length_includes_head=True)
plt.arrow(0, 0, j[0], j[1], color='r', label='j', head_length=.2, head_width=.1, length_includes_head=True)

plt.title('Stretches in SVD')
plt.xlim(-1, 6)
plt.ylim(-1, 6)
plt.legend()

plt.rcParams["figure.figsize"] = (10,5)
plt.grid()
# Out:
# No handles with labels found to put in legend.

# %%
from scipy.linalg import svd
# """
# SVD on image compression
# """
 
import numpy as np
import matplotlib.pyplot as plt
from skimage import data
from skimage.color import rgb2gray
 
cat = data.chelsea()
plt.imshow(cat)
# convert to grayscale
gray_cat = rgb2gray(cat)
 
# calculate the SVD and plot the image
U,S,V_T = svd(gray_cat, full_matrices=False)
S = np.diag(S)
fig, ax = plt.subplots(5, 2, figsize=(8, 20))
 
curr_fig=0
for r in [5, 10, 70, 100, 200]:
  cat_approx =U[:, :r] @  S[0:r, :r] @ V_T[:r, :]
  ax[curr_fig][0].imshow(256-cat_approx)
  ax[curr_fig][0].set_title("k = "+str(r))
  ax[curr_fig,0].axis('off')
  ax[curr_fig][1].set_title("Original Image")
  ax[curr_fig][1].imshow(gray_cat)
  ax[curr_fig,1].axis('off')
  curr_fig +=1
plt.show()
