# %%
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

rng = np.random.RandomState(1)
X = np.dot(rng.rand(3, 3), rng.randn(3, 200)).T
pca = PCA(n_components=1)
pca.fit(X)
X_pca = pca.transform(X)
X_new = pca.inverse_transform(X_pca)
plt.scatter(X[:, 0], X[:, 1], alpha=0.2)
plt.scatter(X_new[:, 0], X_new[:, 1], alpha=0.8)
plt.axis('equal');

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
rng = np.random.RandomState(1)
X = np.dot(rng.rand(2, 2), rng.randn(2, 200)).T
plt.scatter(X[:, 0], X[:, 1])
plt.axis('equal')
# Out:
# (-2.7292712056271964,
#  2.5702744393352615,
#  -0.9326181575178751,
#  1.004413830229183)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(X)
# Out:
# PCA(n_components=2)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.97634101, 0.02365899])

# %%
toPlot = np.cumsum([0, *pca.explained_variance_ratio_])

# %%
plt.plot(toPlot, marker="o")
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %%
pca.components_
# Out:
# array([[-0.94446029, -0.32862557],
#        [-0.32862557,  0.94446029]])

# %%
pca.explained_variance_
# Out:
# array([0.7625315, 0.0184779])

# %%
def draw_vector(v0, v1, ax=None):
    ax = ax or plt.gca()
    arrowprops=dict(arrowstyle='->',
                    linewidth=2,
                    shrinkA=0, shrinkB=0, color='k')
    ax.annotate('', v1, v0, arrowprops=arrowprops)

# plot data
plt.scatter(X[:, 0], X[:, 1], alpha=0.2)
for length, vector in zip(pca.explained_variance_, pca.components_):
    v = vector * 3 * np.sqrt(length)
    draw_vector(pca.mean_, pca.mean_ + v)
plt.axis('equal');

# %%
pca = PCA(n_components=1)
pca.fit(X)
X_pca = pca.transform(X)
print("original shape:   ", X.shape)
print("transformed shape:", X_pca.shape)
# Out:
# original shape:    (200, 2)
# transformed shape: (200, 1)

# %%
X_new = pca.inverse_transform(X_pca)
plt.scatter(X[:, 0], X[:, 1], alpha=0.2)
plt.scatter(X_new[:, 0], X_new[:, 1], alpha=0.8)
plt.axis('equal');

# %%
from sklearn.datasets import load_digits
digits = load_digits()
digits.data.shape
# Out:
# (1797, 64)

# %%
pca = PCA(2)  # project from 64 to 2 dimensions
projected = pca.fit_transform(digits.data)
print(digits.data.shape)
print(projected.shape)
# Out:
# (1797, 64)
# (1797, 2)

# %%
plt.scatter(projected[:, 0], projected[:, 1],
            c=digits.target, edgecolor='none', alpha=0.5, cmap='BuGn_r')
plt.xlabel('component 1')
plt.ylabel('component 2')
plt.colorbar();

# %%
pca = PCA().fit(digits.data)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from sklearn.decomposition import PCA
rng = np.random.RandomState(1)
X = np.dot(rng.rand(3, 3), rng.randn(3, 200)).T
X.shape
# Out:
# (200, 3)

# %%
rng.rand(3, 3)
# Out:
# array([[0.50574202, 0.1895517 , 0.96498892],
#        [0.29421569, 0.10345956, 0.1443154 ],
#        [0.01409229, 0.7159457 , 0.56449832]])

# %%
plt.scatter(X[:, 0], X[:, 1])
plt.axis('equal')
pca = PCA()
pca.fit(X)
# Out:
# PCA()

# %%
import numpy as np
from sklearn.decomposition import PCA
 
rng = np.random.RandomState(1)
X = np.dot(rng.rand(3, 3), rng.randn(3, 200)).T
X[:3]
# Out:
# array([[-2.53910722, -0.99972052, -1.05081917],
#        [-0.17386061,  0.21758122, -0.07237332],
#        [-1.65349909, -0.53922349, -0.69874396]])

# %%
pca = PCA(n_components=1)
pca.fit(X)
X_pca = pca.transform(X)
X_pca[:3]
# Out:
# array([[-2.99441315],
#        [-0.20185722],
#        [-1.953744  ]])

# %%
dif = (X[:, 0] - X_pca[:, 0])[:30]
dif.shape
# Out:
# (30,)

# %%
dif[:10]
# Out:
# array([ 0.45530593,  0.02799661,  0.30024492, -0.02072381,  0.10519907,
#         0.17293983,  0.11609898,  0.08399806, -0.01563563, -0.01430768])

# %%
component_1 = pca.components_[0]
component_1
# Out:
# array([0.85060474, 0.28738969, 0.44031664])

# %%
scores = X @ pca.components_.T
scores[:15]
# Out:
# array([[-2.90977917],
#        [-0.11722324],
#        [-1.86911002],
#        [-0.74170774],
#        [ 0.3464752 ],
#        [-0.43608162],
#        [-0.1985933 ],
#        [ 0.03263819],
#        [-0.40549808],
#        [ 0.29994906],
#        [-0.8329152 ],
#        [-0.28066176],
#        [ 0.45382023],
#        [ 0.13562491],
#        [ 1.20252219]])

# %%
X_pca[:15]
# Out:
# array([[-2.99441315],
#        [-0.20185722],
#        [-1.953744  ],
#        [-0.82634172],
#        [ 0.26184122],
#        [-0.5207156 ],
#        [-0.28322728],
#        [-0.05199579],
#        [-0.49013206],
#        [ 0.21531508],
#        [-0.91754918],
#        [-0.36529574],
#        [ 0.36918625],
#        [ 0.05099092],
#        [ 1.11788821]])

# %%
X_mean = X.mean(axis=0)
X_nrm = X - X_mean
scores = X_nrm @ pca.components_.T
scores[:15]
# Out:
# array([[-2.99441315],
#        [-0.20185722],
#        [-1.953744  ],
#        [-0.82634172],
#        [ 0.26184122],
#        [-0.5207156 ],
#        [-0.28322728],
#        [-0.05199579],
#        [-0.49013206],
#        [ 0.21531508],
#        [-0.91754918],
#        [-0.36529574],
#        [ 0.36918625],
#        [ 0.05099092],
#        [ 1.11788821]])
