# %%
import numpy as np
A = np.array([[1,2],
              [2,3]             
              ])
AtA = A.T @ A
valAtA, vecAtA = np.linalg.eig(AtA)

# %% [markdown]
# Which of the following vectors s1, s2, s3 and s4 contain singular values of matrix A?

# %%
U, s1, VH = np.linalg.svd(A)

# %%
s2 = valAtA

# %%
s3 = np.sqrt(valAtA)

# %%
s4 = vecAtA

# %%
s1 == s3
# Out:
# array([False, False])

# %%
s1, s3
# Out:
# (array([4.23606798, 0.23606798]), array([0.23606798, 4.23606798]))

# %%
U, S, VH = np.linalg.svd(A)
print(valAtA)
ascRootValAtA = np.sort(np.sqrt(valAtA))
descRootValAtA1 = ascRootValAtA[::-1]
descRootValAtA1
descRootValAtA2 = np.sort(ascRootValAtA)[::-1]
descRootValAtA2 = -np.sort(-ascRootValAtA)
descRootValAtA2
descRootValAtA1 == descRootValAtA2
descRootValAtA1 == S
np.isclose(descRootValAtA1, S)
np.isclose(descRootValAtA2, S)
np.isclose(descRootValAtA1, descRootValAtA2)
# Out:
# [ 0.05572809 17.94427191]
# array([ True,  True])

# %%
import numpy as np
A = np.array([[1,2, 3],
              [4, 5, 6]              
              ])
AtA = A.T @ A

valAtA, vecAtA = np.linalg.eig(AtA)
U, S, VH = np.linalg.svd(A)
np.sqrt(valAtA)
# Out:
# array([9.50803200e+00, 7.72869636e-01, 2.68942198e-08])

# %%
ascRootValAtA = np.sort(np.sqrt(valAtA))
ascRootValAtA
# Out:
# array([2.68942198e-08, 7.72869636e-01, 9.50803200e+00])

# %%
ascRootValAtA[::-1]
# Out:
# array([9.50803200e+00, 7.72869636e-01, 2.68942198e-08])

# %%
np.sort(ascRootValAtA)[::-1]
# Out:
# array([9.50803200e+00, 7.72869636e-01, 2.68942198e-08])

# %%
-np.sort(-ascRootValAtA)
# Out:
# array([9.50803200e+00, 7.72869636e-01, 2.68942198e-08])
