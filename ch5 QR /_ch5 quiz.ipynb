# %%
from scipy.linalg import orth
from sympy.matrices import Matrix
import sympy
import numpy as np
from sympy import init_printing
init_printing()

# %% [markdown]
# # Initialize different matrixes

# %%
#A = np.array([[0, 1], [1, 0]]); symA = Matrix(A)  
A = np.array([[1, 2], [3, 4]]); symA = Matrix(A)  
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
symA
# Out:
# ⎡1  2⎤
# ⎢    ⎥
# ⎣3  4⎦

# %% [markdown]
# #1. What is dimension of col(A)?

# %%
np.linalg.matrix_rank(A)
# Out:
# 2

# %%
symA.rank()
# Out:
# 2

# %%
symA.columnspace()
# Out:
# ⎡⎡1⎤  ⎡2⎤⎤
# ⎢⎢ ⎥, ⎢ ⎥⎥
# ⎣⎣3⎦  ⎣4⎦⎦

# %% [markdown]
# #2. is A orthogonal?

# %%
np.allclose(A.T @ A, np.eye(A.shape[0]))
# Out:
# False

# %% [markdown]
# #3. compute its l1 norm
#
# Norm
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.linalg.norm.html

# %%
np.linalg.norm(A, ord=1)
# Out:
# 6.0

# %%
np.linalg.norm(A, ord=2)
# Out:
# 5.464985704219043

# %%
np.linalg.norm(A, ord=np.inf)
# Out:
# 7.0

# %%
import math
from math import sqrt
sqrt(30)
# Out:
# 5.477225575051661

# %%
sqrt(sqrt(221) + 15)
# Out:
# 5.464985704219043

# %%
symA.norm(ord=2)
# Out:
#   ___________
# ╲╱ √221 + 15

# %%
symA.norm()
# Out:
# √30

# %%
# symA.norm(ord=1)
# symA.norm(1) # fails

# %%
# symA.norm(ord=1) # fails
# symA.norm(1) # fails
symA.norm(2)
# Out:
#   ___________
# ╲╱ √221 + 15

# %% [markdown]
# #4. compute Ainv

# %%
np.linalg.inv(A)
# Out:
# array([[-2. ,  1. ],
#        [ 1.5, -0.5]])

# %%
symA.inv()
# Out:
# ⎡-2    1  ⎤
# ⎢         ⎥
# ⎣3/2  -1/2⎦

# %% [markdown]
# #5. compute At

# %%
A.T
# Out:
# array([[1, 3],
#        [2, 4]])

# %%
A.transpose()
# Out:
# array([[1, 3],
#        [2, 4]])

# %%
symA.T
# Out:
# ⎡1  3⎤
# ⎢    ⎥
# ⎣2  4⎦

# %%
symA.transpose()
# Out:
# ⎡1  3⎤
# ⎢    ⎥
# ⎣2  4⎦

# %% [markdown]
# #6. compare Ainv to At

# %%
np.allclose(A.T, np.linalg.inv(A))
# Out:
# False

# %%
np.isclose(A.T, np.linalg.inv(A))
# Out:
# array([[False, False],
#        [False, False]])

# %%
A.T - np.linalg.inv(A)
# Out:
# array([[3. , 2. ],
#        [0.5, 4.5]])

# %% [markdown]
# #7. compute l1 norm of Ainv and A

# %%
normAinv = np.linalg.norm(np.linalg.inv(A), ord=1)
normAinv
# Out:
# 3.499999999999999

# %%
normA = np.linalg.norm(A, ord=1)
normA
# Out:
# 6.0

# %% [markdown]
# Condition number by multiplication normAinv * normA

# %%
normAinv * normA
# Out:
# 20.999999999999993

# %% [markdown]
# #8. compute its condition number

# %%
np.linalg.cond(A, p=1)
# Out:
# 20.999999999999993

# %% [markdown]
# #9. compute AtA

# %%
A.T @ A
# Out:
# array([[10, 14],
#        [14, 20]])

# %% [markdown]
# check A for orthogonality by comparing AtA to an identity matrix

# %%
np.allclose(A.T @ A, np.identity(A.shape[1]))
# Out:
# False

# %% [markdown]
# #10. compute its l1 norm

# %%
np.linalg.norm(A.T @ A, ord=1)
# Out:
# 34.0

# %% [markdown]
# #11. compute its inverse AtAinv

# %%
np.linalg.inv(A.T @ A)
# Out:
# array([[ 5. , -3.5],
#        [-3.5,  2.5]])

# %%
np.allclose(np.linalg.inv(A.T @ A), np.identity(A.shape[1]))
# Out:
# False

# %% [markdown]
# #12. compute l1 norm of AtAinv

# %%
np.linalg.norm(np.linalg.inv(A.T @ A), ord=1)
# Out:
# 8.50000000000003

# %% [markdown]
# #13. compute condition number of AtA

# %%
np.linalg.cond(A.T @ A, p=1)
# Out:
# 289.000000000001

# %% [markdown]
# Check it by multiplication

# %%
np.linalg.norm(np.linalg.inv(A.T @ A), ord=1) * np.linalg.norm(A.T @ A, ord=1)
# Out:
# 289.000000000001

# %% [markdown]
# #14. compare condition numbers of A and AtA

# %%
np.linalg.cond(A, p=1), np.linalg.cond(A.T @ A, p=1)
# Out:
# (20.999999999999993, 289.000000000001)

# %% [markdown]
# ------------------------------------------

# %% [markdown]
# #projection of a vector onto a vector

# %% [markdown]
# Denote
# a = (1, 2)T, b = (3, 4)T.
# Compute
# proj a  b

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = np.array([1, 2])
b = np.array([3, 4])
np.dot(a, b) / (np.linalg.norm(a)**2)
# Out:
# 2.1999999999999997

# %%
11/5 == 2.2
# Out:
# True

# %%
(np.dot(a, b) / np.linalg.norm(a)**2)*a
# Out:
# array([2.2, 4.4])

# %% [markdown]
# #Gram-Schmidt

# %% [markdown]
# Denote
# v1 = (1, 0, 0)
# v2 = (1, 1, 0)
# v3 = (1, 1, 1)
#
#
# Orthogonzlize it, giving a1, a2, a3.

# %%
v1 = np.array([1, 0, 0])
v2 = np.array([1, 1, 0])
v3 = np.array([1, 1, 1])

# %%
a1 = np.copy(v1)

# %%
(np.dot(v2, a1) / (np.linalg.norm(a1))**2)*a1
# Out:
# array([1., 0., 0.])

# %%
a2 = v2 - (np.dot(v2, a1) / np.linalg.norm(a1)**2)*a1
a2
# Out:
# array([0., 1., 0.])

# %%
a3 = v3 - np.dot(v3, a1) / np.linalg.norm(a1)*a1 - np.dot(v3, a2) / np.linalg.norm(a2)*a2
a3
# Out:
# array([0., 0., 1.])

# %% [markdown]
# ----------------------------

# %% [markdown]
# stopped here

# %% [markdown]
# #Projection of a vector onto a plain

# %%
v1 = np.array((1, 0, 0))
v2 = np.array((1, 1, 0))
b = np.array((1, 2, 3))

# %%
a1 = np.copy(v1)

# %%
a2 = v2 - (np.dot(v2, a1) / np.linalg.norm(a1)**2)*a1
a2
# Out:
# array([0., 1., 0.])

# %% [markdown]
# ## 5. Compute proj a1 b

# %%
proj_b_on_a1 = (np.dot(b, a1) / (np.linalg.norm(a1))**2)*a1
proj_b_on_a1
# Out:
# array([1., 0., 0.])

# %% [markdown]
# ##6. Compute proj a2 b

# %%
proj_b_on_a2 = (np.dot(b, a2) / (np.linalg.norm(a2))**2)*a2
proj_b_on_a2
# Out:
# array([0., 2., 0.])

# %% [markdown]
# ##7. Compute bHat = proj {a1, a2} b

# %%
bHat = proj_b_on_a1 + proj_b_on_a2
bHat
# Out:
# array([1., 2., 0.])

# %% [markdown]
# ##8. Find a residual vector r = b - bHat

# %%
r = b - bHat
r
# Out:
# array([0., 0., 3.])

# %% [markdown]
# ##9. Compute the following dot products
#
# 		a. (v1.v2) = 1
# 		b. (a1.a2)= 0
# 		c. (r.v1) = 0
# 		d. (r.v2)=0
# 		e. (r.a1)=0
# 		f. (r.a2)=0
# 		g. (r.b)=9
#         h. (r.bHat)=0

# %%
vectors1 = [v1, a1, r, r, r, r, r, r]
vectors2 = [v2, a2, v1, v2, a1, a2, b, bHat]

# %%
labels = ["v1 dot v2: ",
"a1 dot a2: ",
"r dot v1: ",
"r dot v2: ",
"r dot a1: ",
"r dot a2: ",
"r dot b: ",
"r dot bHat "] 
for i,j,k in zip(vectors1, vectors2, labels):
  print(k, str(i.dot(j)))
# Out:
# v1 dot v2:  1
# a1 dot a2:  0.0
# r dot v1:  0.0
# r dot v2:  0.0
# r dot a1:  0.0
# r dot a2:  0.0
# r dot b:  9.0
# r dot bHat  0.0

# %%
v1.dot(v2)
# Out:
# 1

# %%
a1.dot(a2)
# Out:
# 0.0

# %%
r.dot(v1)
# Out:
# 0.0

# %%
r.dot(v2)
# Out:
# 0.0

# %%
r.dot(a1)
# Out:
# 0.0

# %%
r.dot(a2)
# Out:
# 0.0

# %%
r.dot(b)
# Out:
# 9.0

# %%
r.dot(bHat)
# Out:
# 0.0

# %% [markdown]
# ##10. Check the following orthogonality statements
# (Choose all that apply. None, one or more items can be chosen)
#
# 		a. v1 \orth v2 False
# 		b. a1 \orth a2 True
# 		c. r \orth v1 True
# 		d. r \orth v2 True
# 		e. r \orth a1True
# 		f. r \orth a2True
# 		g. r\orth b False
# 		h. r\orthbHat True

# %%
labels = ["v1 orth v2: ",
"a1 orth a2: ",
"r orth v1: ",
"r orth v2: ",
"r orth a1: ",
"r orth a2: ",
"r orth b: ",
"r orth bHat: "] 

for i,j,k in zip(vectors1, vectors2, labels):
  print(k, str(not i.dot(j)))
# Out:
# v1 orth v2:  False
# a1 orth a2:  True
# r orth v1:  True
# r orth v2:  True
# r orth a1:  True
# r orth a2:  True
# r orth b:  False
# r orth bHat:  True

# %%
not v1.dot(v2)
# Out:
# False

# %%
not a1.dot(a2)
# Out:
# True

# %%
not r.dot(v1)
# Out:
# True

# %%
not r.dot(v2)
# Out:
# True

# %%
not r.dot(a1)
# Out:
# True

# %%
not r.dot(a2)
# Out:
# True

# %%
not r.dot(b)
# Out:
# False

# %%
not r.dot(bHat)
# Out:
# True

# %% [markdown]
# stopped
# #simple 2 by 2 QR examples

# %%
M = np.array([[1, 0], [0, 1]])
M = Matrix(M)

# %%
Q, R = M.QRdecomposition()
Q, R
# Out:
# ⎛⎡1  0⎤  ⎡1  0⎤⎞
# ⎜⎢    ⎥, ⎢    ⎥⎟
# ⎝⎣0  1⎦  ⎣0  1⎦⎠

# %%
M = np.array([[1, 1], [0, 1]])
M = Matrix(M)

# %%
Q, R = M.QRdecomposition()
Q, R
# Out:
# ⎛⎡1  0⎤  ⎡1  1⎤⎞
# ⎜⎢    ⎥, ⎢    ⎥⎟
# ⎝⎣0  1⎦  ⎣0  1⎦⎠

# %%
M = np.array([[0, 0], [0, 0]])
#M = Matrix(M)

# %%
# %%script false
# Q, R = M.QRdecomposition()
# Q, R

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Q, R = np.linalg.qr(M)
Q, R
# Out:
# (array([[1., 0.],
#         [0., 1.]]), array([[0., 0.],
#         [0., 0.]]))

# %% [markdown]
# # Invertible 2 by 2 QR example

# %%
M = Matrix([[1, 1], [1, 0]])
M.QRdecomposition()
# Out:
# ⎛⎡√2   √2 ⎤  ⎡    √2⎤⎞
# ⎜⎢──   ── ⎥  ⎢√2  ──⎥⎟
# ⎜⎢2    2  ⎥  ⎢    2 ⎥⎟
# ⎜⎢        ⎥, ⎢      ⎥⎟
# ⎜⎢√2  -√2 ⎥  ⎢    √2⎥⎟
# ⎜⎢──  ────⎥  ⎢0   ──⎥⎟
# ⎝⎣2    2  ⎦  ⎣    2 ⎦⎠

# %% [markdown]
# #Rectangular easy matrix QR (no scaling)

# %%
M = Matrix([[1, 1], [0, 1], [0, 0]])
M.QRdecomposition()
# Out:
# ⎛⎡1  0⎤        ⎞
# ⎜⎢    ⎥  ⎡1  1⎤⎟
# ⎜⎢0  1⎥, ⎢    ⎥⎟
# ⎜⎢    ⎥  ⎣0  1⎦⎟
# ⎝⎣0  0⎦        ⎠

# %%
v1 = np.array([1, 0, 0])
v2 = np.array([1, 1, 0])

# %%
a1 = np.copy(v1)
a2 = v2 - (np.dot(v2, a1) / (np.linalg.norm(a1))**2)*a1
a2
# Out:
# array([0., 1., 0.])

# %% [markdown]
# #Householder 2 by 2

# %% [markdown]
# ##Question 9

# %%
M = np.array([[1, 0], [0, -1]])
v = np.array([0, 1])
M @ v
# Out:
# array([ 0, -1])

# %% [markdown]
# ##Question 11

# %%
H = np.array([[1, 0], [0, -1]])
v = np.array([0, 1])
H @ v
# Out:
# array([ 0, -1])

# %% [markdown]
# #K: Householder 2 by 2 new numbers

# %% [markdown]
# ##Question 9

# %%
H = np.array([[1, 0], [0, -1]])
u = np.array([1, 0])
H @ u
# Out:
# array([1, 0])

# %% [markdown]
# #K: Rectangular not easy matrix QR

# %%
A = np.array([[2, -5],
              [3, 3],
              [6, -1]])
Q, R = np.linalg.qr(A)

# %%
Q
# Out:
# array([[-0.28571429,  0.80849333],
#        [-0.42857143, -0.58799515],
#        [-0.85714286,  0.0244998 ]])

# %%
R
# Out:
# array([[-7.        ,  1.        ],
#        [ 0.        , -5.83095189]])

# %%
A_sym = Matrix(A)
A_sym.QRdecomposition()
# Out:
# ⎛⎡     -33⋅√34 ⎤          ⎞
# ⎜⎢2/7  ────────⎥          ⎟
# ⎜⎢       238   ⎥          ⎟
# ⎜⎢             ⎥          ⎟
# ⎜⎢      12⋅√34 ⎥  ⎡7  -1 ⎤⎟
# ⎜⎢3/7   ────── ⎥, ⎢      ⎥⎟
# ⎜⎢       119   ⎥  ⎣0  √34⎦⎟
# ⎜⎢             ⎥          ⎟
# ⎜⎢      -√34   ⎥          ⎟
# ⎜⎢6/7   ─────  ⎥          ⎟
# ⎝⎣       238   ⎦          ⎠

# %%
v1 = np.array([2,3,6])
v2 = np.array([-5, 3, -1])

# %%
a1 = v1 / np.linalg.norm(v1)
a1
# Out:
# array([0.28571429, 0.42857143, 0.85714286])

# %%
_a2 = v2 - v1.dot(a1) / (np.linalg.norm(a1)**2) * a1
_a2
# Out:
# array([-7.0000000e+00, -4.4408921e-16, -7.0000000e+00])

# %%
a2 = _a2 / np.linalg.norm(_a2)
a2
# Out:
# array([-7.07106781e-01, -4.48597845e-17, -7.07106781e-01])

# %%
a1.dot(a2)
# Out:
# -0.8081220356417687

# %% [markdown]
# -------------------------------

# %% [markdown]
# curiosity about QR decomposition of a matrix with incomplete column rank

# %%
unitMatrix = np.array([[1, 1], [1, 1]])
Q, R = np.linalg.qr(unitMatrix)
Q, R
# Out:
# (array([[-0.70710678, -0.70710678],
#         [-0.70710678,  0.70710678]]),
#  array([[-1.41421356e+00, -1.41421356e+00],
#         [ 0.00000000e+00, -4.74426853e-17]]))

# %%
Q @ R
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
symUnitMatrix = Matrix(unitMatrix)
#symUnitMatrix.QRdecomposition()

# %%
rWithZero = np.copy(R)
rWithZero[1, 1] = 0
rWithZero
# Out:
# array([[-1.41421356, -1.41421356],
#        [ 0.        ,  0.        ]])

# %%
Q @ rWithZero
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %% [markdown]
# -------------------

# %% [markdown]
# #How to create random orthonormal matrix in python numpy

# %%
from scipy.stats import ortho_group  # Requires version 0.18 of scipy

m = ortho_group.rvs(dim=3)
m
# Out:
# array([[-0.47803175, -0.14502876, -0.8662865 ],
#        [-0.22848831, -0.93178595,  0.28207807],
#        [ 0.84810302, -0.33277861, -0.41228589]])

# %% [markdown]
# #Detect orthogonality

# %%
np.allclose(m.T @ m, np.eye(m.shape[0]))
# Out:
# True

# %%
non_orth = np.random.randn(3, 3)
non_orth
# Out:
# array([[ 0.22490312,  0.06246645, -0.16157209],
#        [-0.57631993,  0.68586136,  1.55585179],
#        [-0.10909174,  0.356317  , -0.17927633]])

# %%
np.allclose(non_orth.T @ non_orth, np.eye(non_orth.shape[0]))
# Out:
# False
