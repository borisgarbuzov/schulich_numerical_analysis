# %%
import pandas as pd
import numpy as np
import datetime as dt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/1ozmJBOaE2Xh6gjDGqy4TI27XIhyAL6h60QRy1MUsDso/pub?output=csv')
df.head(5)
# Out:
#          Date  Adj Close AAPL  ...  Volume WMT  Volume XOM
# 0  2005-02-21        1.368799  ...    46536700   108879400
# 1  2005-02-28        1.316963  ...    61478000   128760400
# 2  2005-03-07        1.238824  ...    47133000   170203800
# 3  2005-03-14        1.321578  ...   152631200   112404900
# 4  2005-03-21        1.307426  ...    70161800    88667200
#
# [5 rows x 41 columns]

# %%
volume_columns = [col for col in df.columns if 'Volume' in col]
volume_columns
# Out:
# ['Volume AAPL',
#  'Volume ABC',
#  'Volume AMZN',
#  'Volume BAC',
#  'Volume BP',
#  'Volume BRK-B',
#  'Volume CVS',
#  'Volume DDAIF',
#  'Volume F',
#  'Volume GOOG',
#  'Volume JPM',
#  'Volume MCK',
#  'Volume MSFT',
#  'Volume RDS-B',
#  'Volume T',
#  'Volume TM',
#  'Volume TOT',
#  'Volume UNH',
#  'Volume WMT',
#  'Volume XOM']

# %%
df[volume_columns] = df[volume_columns].shift(1)

# %%
# convert `date` column to numerical values
# more precisely number of days since 1st january 1AD
df['Date'] = pd.to_datetime(df['Date'])
df['Date'] = df['Date'].map(dt.datetime.toordinal)

# %%
df = df.dropna()

# %%
X = pd.concat([df[volume_columns], df['Date']], axis=1)
y = df.filter(regex='Adj Close')

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
lm = LinearRegression()
model = lm.fit(X_train, y_train)

# %%
yhat = model.predict(X_test)

print('Coefficients:', model.coef_)
print("MSE: %.2f" % mean_squared_error(y_test, yhat))
print('Coefficient of determination: %.2f'
      % r2_score(y_test, yhat))
# Out:
# Coefficients: [[-6.99843434e-12 -3.28308281e-07 -2.64180409e-09 -8.45617172e-10
#    9.83375229e-10 -3.99189322e-08  4.93055024e-09  3.86968544e-08
#    1.44257857e-08  1.84835201e-07 -4.41382697e-08 -5.09370751e-07
#   -8.68332782e-09 -1.66079290e-07 -1.21044601e-09 -6.36428183e-07
#   -1.05265522e-07 -2.62304203e-08 -3.19306910e-08  2.38269911e-07
#    1.60557799e-02]
#  [-1.44764751e-09  2.09339975e-07 -5.38568242e-10 -2.99407576e-09
#    8.04686213e-09 -1.22815378e-08 -9.26703748e-08  8.26388473e-08
#   -1.60398529e-08 -1.00489298e-08 -3.57858848e-08 -2.08217388e-07
#    7.16203863e-10  9.91347005e-08  1.19656742e-08  7.96940639e-08
#   -1.95460671e-07 -4.74129625e-08  5.66910696e-08  4.11856008e-08
#    1.55580012e-02]
#  [-1.10543206e-08 -1.14826568e-05  1.60361750e-06 -1.07421865e-07
#   -1.10338577e-07 -8.27808651e-07  2.16873122e-06  1.79995348e-06
#    5.12993413e-07  7.51937164e-06 -9.17465963e-07 -1.11568306e-05
#   -2.56607348e-07 -2.07665821e-06 -4.53507113e-08 -2.19874176e-05
#   -6.26867321e-06 -1.02981549e-07  4.05468168e-07  5.33474707e-06
#    5.11387332e-01]
#  [ 5.80731943e-10 -2.31726839e-07  6.03865050e-08 -7.88555525e-09
#   -8.10345761e-09 -1.99411748e-08  8.15788925e-08  9.67189521e-08
#    1.96873789e-09  1.02908090e-07 -3.44889617e-08  1.10431322e-07
#   -8.69490184e-09 -5.12401694e-08  4.46374534e-09 -4.62898167e-07
#   -2.98550502e-07  1.64770026e-08  4.98329202e-08  4.13022673e-08
