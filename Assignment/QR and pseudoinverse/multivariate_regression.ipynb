# %%
import pandas as pd
import numpy as np
import datetime as dt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/1ozmJBOaE2Xh6gjDGqy4TI27XIhyAL6h60QRy1MUsDso/pub?output=csv')
df.head(5)
# Out:
#          Date  Adj Close AAPL  ...  Volume WMT  Volume XOM
# 0  2005-02-21        1.368799  ...    46536700   108879400
# 1  2005-02-28        1.316963  ...    61478000   128760400
# 2  2005-03-07        1.238824  ...    47133000   170203800
# 3  2005-03-14        1.321578  ...   152631200   112404900
# 4  2005-03-21        1.307426  ...    70161800    88667200
#
# [5 rows x 41 columns]

# %%
volume_columns = [col for col in df.columns if 'Volume' in col]
volume_columns
# Out:
# ['Volume AAPL',
#  'Volume ABC',
#  'Volume AMZN',
#  'Volume BAC',
#  'Volume BP',
#  'Volume BRK-B',
#  'Volume CVS',
#  'Volume DDAIF',
#  'Volume F',
#  'Volume GOOG',
#  'Volume JPM',
#  'Volume MCK',
#  'Volume MSFT',
#  'Volume RDS-B',
#  'Volume T',
#  'Volume TM',
#  'Volume TOT',
#  'Volume UNH',
#  'Volume WMT',
#  'Volume XOM']

# %%
df[volume_columns] = df[volume_columns].shift(1)

# %%
# convert `date` column to numerical values
# more precisely number of days since 1st january 1AD
df['Date'] = pd.to_datetime(df['Date'])
df['Date'] = df['Date'].map(dt.datetime.toordinal)

# %%
df = df.dropna()

# %%
X = pd.concat([df[volume_columns], df['Date']], axis=1)
y = df.filter(regex='Adj Close')

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
lm = LinearRegression()
model = lm.fit(X_train, y_train)

# %%
yhat = model.predict(X_test)

print('Coefficients:', model.coef_)
print("MSE: %.2f" % mean_squared_error(y_test, yhat))
print('Coefficient of determination: %.2f'
      % r2_score(y_test, yhat))
# Out:
# Coefficients: [[-6.96153573e-10 -2.93169294e-07  2.04519277e-08 -2.54991619e-10
#    6.31001995e-09 -3.90075769e-08 -1.69709567e-08  4.97429793e-08
#    1.67358843e-08  1.95641220e-07 -5.50100836e-08 -5.48018504e-07
#   -1.32969930e-08 -1.18833603e-07  5.84240046e-10 -7.29705140e-07
#   -1.15793975e-07 -3.07259175e-08 -4.58884139e-08  2.51381022e-07
#    1.51591720e-02]
#  [-1.70785068e-09  2.06391540e-07  1.63927450e-08 -2.82106238e-09
#    1.22221128e-08 -1.17324260e-08 -9.62251754e-08  7.01862801e-08
#   -1.27038609e-08 -7.59808975e-09 -3.71739139e-08 -2.04173339e-07
#    2.44367039e-09  1.26991728e-07  9.02246669e-09  6.41224610e-08
#   -1.92342691e-07 -5.27925147e-08  6.24435214e-08  3.60244281e-08
#    1.55263308e-02]
#  [-3.97765075e-08 -1.05359290e-05  2.69261950e-06 -1.05218448e-07
#   -3.78893722e-08 -6.78876524e-07  1.54876454e-06  2.24633227e-06
#    5.40071174e-07  7.88671100e-06 -1.21341395e-06 -1.20947738e-05
#   -3.40593283e-07 -1.35800135e-06  1.09177929e-07 -2.62944656e-05
#   -6.28079056e-06 -4.93757376e-07  1.90183387e-07  5.65317125e-06
#    4.82169593e-01]
#  [ 4.01869198e-10 -1.95338568e-07  7.81067933e-08 -8.52259195e-09
#   -7.80621862e-09 -1.69785346e-08  6.57437043e-08  1.11274719e-07
#    3.02166939e-09  1.03627513e-07 -3.73948503e-08  1.11130230e-07
#   -8.19274470e-09 -6.80290684e-08  1.10259435e-08 -5.35280725e-07
#   -2.66912442e-07  2.07571258e-08  5.38197618e-08  3.43874477e-08
#    7.51415927e-04]
#  [ 2.75912330e-10 -1.24392565e-07  3.74291192e-08 -2.93425661e-09
#   -2.27379711e-08  6.45300491e-09  3.54953648e-08  2.33707718e-08
#    7.00485366e-10  1.92854175e-08 -6.32878836e-09  9.32700197e-08
#   -1.74468360e-09 -1.69402881e-07  1.72482473e-08 -3.69498874e-08
#   -1.11458099e-07  6.71558745e-08  1.01504492e-08 -3.92464959e-08
#    5.90570816e-04]
#  [-5.25651779e-10 -2.52163994e-07  1.55886586e-07 -1.86297252e-08
#    8.49194133e-10 -3.62661892e-08  7.25990965e-08  1.24934572e-07
#   -1.50117458e-09  2.11539446e-07 -3.05360092e-08  1.91080450e-07
#   -8.20315011e-09 -5.86720944e-07  1.89573264e-08 -3.91926448e-07
#   -5.68442398e-07  2.93017478e-08  1.14969330e-07  6.00850211e-08
#    3.52856818e-02]
#  [-3.34439595e-10  4.47603388e-07  1.35200812e-08 -2.56409739e-09
#    5.40522558e-09 -4.60191772e-08 -1.50177984e-07  2.28042464e-08
#   -2.05368463e-08 -1.23881789e-07 -1.29655808e-08 -1.44965094e-07
#   -3.55963425e-09  3.17454378e-07  7.12706639e-09  5.06176066e-07
#   -2.13843975e-07 -2.54406934e-08  9.79311180e-08 -4.18423344e-08
#    8.79349813e-03]
#  [ 1.54611660e-09 -8.85516638e-08  5.48604076e-08 -6.09102064e-09
#    9.38581522e-09 -2.48509766e-08  1.48410698e-09  1.77238368e-07
#   -4.32851347e-09 -1.39968909e-07 -2.62324543e-08 -2.97612022e-08
#   -6.39259564e-09 -2.99824955e-07  2.48701615e-08 -6.75468635e-08
#   -1.24974784e-07  1.40862109e-08  8.49895933e-08 -6.31344118e-08
#    3.44687065e-03]
#  [-1.97984660e-10  6.61908114e-08 -1.50154320e-08  5.92542752e-10
#    5.69304475e-09  8.51666113e-09 -1.30842718e-08  1.40720922e-08
#    5.75239268e-10 -1.66038285e-08 -7.68416193e-09 -7.31950813e-09
#    2.76252386e-09 -4.96380877e-08  4.23836202e-10  1.12221320e-07
#    2.25534474e-08 -7.49081228e-09 -1.24048998e-08 -1.42514626e-08
#    4.31432024e-04]
#  [-1.35065566e-08 -3.69598277e-06  1.17124422e-06 -5.82700615e-08
#   -7.75551807e-09 -6.21477087e-07  5.41668668e-07  5.57673753e-07
#    1.83809318e-07  2.95755587e-06 -7.52352331e-07 -2.34864767e-06
#   -2.36298963e-07 -1.74907419e-06  4.24925154e-08 -7.74901672e-06
#   -4.36054791e-06  1.85063542e-07  4.86605622e-07  2.06816545e-06
#    2.64595063e-01]
#  [-9.57350543e-10 -2.63731904e-07  1.07875798e-07 -7.60863119e-09
#   -7.50960162e-09 -4.45041088e-08  8.45492405e-08  1.83457955e-07
#    1.14428448e-08  2.25088516e-07 -5.51725930e-08  2.11525043e-07
#   -1.49903968e-08 -4.93287781e-07  1.39826950e-08 -5.98490739e-07
#   -3.55577500e-07  7.09546690e-08  5.31785391e-08  8.59758865e-08
#    1.99039757e-02]
#  [-9.34157171e-10  6.99433560e-07 -1.05984935e-07 -3.74810794e-09
#    4.75968625e-08 -4.97034786e-08 -3.19367753e-07 -8.81055983e-10
#   -4.38805469e-08 -3.00404831e-07 -3.86510668e-08 -6.19204617e-07
#    9.98872772e-09  4.23116008e-07  2.81561116e-08  1.10149957e-06
#   -5.52535194e-07 -8.67886708e-08  1.71917660e-08  2.70472249e-09
#    1.96524188e-02]
#  [-1.76074188e-09 -8.01953929e-07  1.51484851e-07 -7.60064327e-09
#    4.71741984e-10 -6.08655396e-08  8.76366865e-08  1.71837716e-07
#    3.75009498e-08  5.05825844e-07 -9.28587872e-08 -6.93162574e-07
#   -2.60415356e-08  9.04791640e-08 -1.16825054e-08 -1.69854935e-06
#   -5.47845669e-07  2.58744507e-08 -6.22285607e-08  4.38836359e-07
#    2.95203937e-02]
#  [ 1.06064936e-09 -5.45490914e-08  6.61048881e-09 -3.49738098e-09
#   -2.48223580e-08  1.90785141e-08  4.44721428e-08  6.32723106e-09
#   -7.50198288e-09 -4.07753618e-08  1.09287023e-08  1.48973088e-07
#    6.16098042e-09 -4.70190254e-07  3.24716720e-08 -1.28430419e-07
#    1.53031528e-07  2.82852425e-08 -3.55683292e-08 -1.17741705e-07
#    3.97916445e-03]
#  [ 7.90928812e-10  3.66707124e-08  1.90468284e-11 -1.94844693e-09
#   -8.29104336e-09 -1.33091369e-08  9.64397918e-09  2.63282010e-08
#   -2.55719435e-09 -2.75574580e-08  2.38796017e-09  6.88233709e-08
#   -2.19631042e-09  6.53736424e-08 -1.04820815e-08  1.35379105e-08
#   -8.64626255e-10 -2.07565744e-10  6.92753598e-09 -2.40558475e-08
#    3.93839744e-03]
#  [ 1.82568879e-09 -2.40838685e-07  4.86830886e-09 -8.40613166e-09
#   -1.30854312e-08 -7.24424824e-08  3.46523254e-08  1.16070383e-07
#   -8.97724177e-09 -1.44449850e-08 -6.58993892e-08 -7.39589824e-08
#   -1.62336429e-09  1.10635430e-07  5.06237258e-08 -3.05908111e-07
#   -7.91830258e-07  6.44116415e-08  3.04349261e-08  4.17170891e-08
#    1.21988986e-02]
#  [ 4.44724688e-10 -1.46029776e-07  4.84147256e-08 -4.01775458e-09
#   -1.19097222e-08 -3.52584656e-09  3.06250360e-08  3.61190340e-08
#   -4.08615845e-10 -7.30076138e-09  1.02912984e-09  5.56840070e-08
#   -3.24067838e-09 -2.32669644e-07  1.88254073e-08 -7.12041250e-08
#   -1.53106193e-07  4.28056118e-08  2.17289133e-08 -3.72211719e-08
#    3.69537223e-03]
#  [-5.66495276e-09 -8.40153357e-07  3.93590256e-07 -1.87615111e-08
#   -3.51913931e-08 -7.97152272e-08  2.12411434e-07  3.22713546e-07
#    2.27822052e-08  8.94945027e-07 -1.49682354e-07 -3.85126010e-07
#   -4.08038070e-08 -2.50883135e-07  4.05043877e-08 -2.86627630e-06
#   -7.01682446e-07 -1.26873971e-07  1.35653936e-07  4.17398281e-07
#    5.47667844e-02]
#  [-1.87491451e-10 -2.88060344e-07  4.42062843e-09 -5.20172716e-09
#   -1.03804053e-08 -2.53631176e-08  1.27873997e-08 -1.29347212e-08
#    8.78483979e-09  1.76657967e-07 -1.07245907e-08 -3.79126836e-07
#   -1.14005978e-09 -4.81062090e-08  1.12549747e-08 -5.74464779e-07
#   -2.95618922e-07  1.09060973e-08 -1.20679402e-07  1.85026724e-07
#    1.68090275e-02]
#  [ 2.09547378e-09  1.36063229e-07 -1.88563138e-08 -2.96943317e-09
#   -3.05456442e-08 -2.66757883e-08  1.36122729e-08  1.82648294e-08
#   -1.16357962e-08 -1.50567327e-07  3.69748417e-08  8.97671582e-08
#    3.21553576e-09 -2.23921990e-07  1.14432373e-08  3.95371755e-07
#    4.17797883e-08 -1.18190308e-08  1.32081228e-08 -1.42414386e-07
#    3.80724332e-03]]
# MSE: 5987.18
# Coefficient of determination: 0.76
