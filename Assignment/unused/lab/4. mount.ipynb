# %%
! pwd
! ls
! dir
! dir /
# Out:
# /content
# drive  sample_data
# drive  sample_data
# bin	 datalab  home	 lib64	opt	    root  srv		     tmp    var
# boot	 dev	  lib	 media	proc	    run   sys		     tools
# content  etc	  lib32  mnt	python-apt  sbin  tensorflow-1.15.2  usr

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
os.system("ls") # Not what we want
# Out:
# 0

# %%
print(os.popen("ls").read())
# Out:
# drive
# sample_data

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! ls /content/drive
# Out:
# MyDrive

# %%
! ls "/content/drive/MyDrive/Colab Notebooks"
# Out:
#  Colab		'neural networks'	  python
#  miscellaneous	'Occ Anomaly detection'   York

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/York/numeric_analysis/Assignment/M/finances.csv')
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-49-7e2dd92da832> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/York/numeric_analysis/Assignment/M/finances.csv')
#       3 df.head(5)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
