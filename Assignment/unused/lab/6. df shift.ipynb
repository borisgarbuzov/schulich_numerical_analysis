# %% [markdown]
# df_aapl['Volume AAPL'] = df_aapl['Volume AAPL'].shift(1)

# %%
myMatrix = [[1, 10],
            [2, 20],
            [3, 30]
            ]

# %%
import pandas as pd
df = pd.DataFrame(myMatrix, columns=["x", "y"])
df
# Out:
#    x   y
# 0  1  10
# 1  2  20
# 2  3  30

# %%
xSeries = df['x']
xSeries
# Out:
# 0    1
# 1    2
# 2    3
# Name: x, dtype: int64

# %%
ySeries = df['y']
ySeries
# Out:
# 0    10
# 1    20
# 2    30
# Name: y, dtype: int64

# %%
type(ySeries)
# Out:
# pandas.core.series.Series

# %%
ySeries.shift(1)
# Out:
# 0     NaN
# 1    10.0
# 2    20.0
# Name: y, dtype: float64

# %%
df
# Out:
#    x   y
# 0  1  10
# 1  2  20
# 2  3  30

# %%
ySeries
# Out:
# 0    10
# 1    20
# 2    30
# Name: y, dtype: int64

# %%
ySeries = ySeries.shift(1)
ySeries
# Out:
# 0     NaN
# 1    10.0
# 2    20.0
# Name: y, dtype: float64

# %%
df
# Out:
#    x   y
# 0  1  10
# 1  2  20
# 2  3  30

# %%
df['y'] = ySeries.shift(1)
df
# Out:
#    x     y
# 0  1   NaN
# 1  2   NaN
# 2  3  10.0

# %%
ySeries
# Out:
# 0     NaN
# 1    10.0
# 2    20.0
# Name: y, dtype: float64

# %%
df['y'] = ySeries.shift(-1)
df
# Out:
#    x     y
# 0  1  10.0
# 1  2  20.0
# 2  3   NaN
