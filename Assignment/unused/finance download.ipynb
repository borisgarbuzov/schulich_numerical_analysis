# %%
#!pip install yfinance

# %%
import yfinance as yf
data = yf.download(tickers="AAPL AMZN FB MSFT TSLA BMWYY DMLRY", period="5y")
data.shape
# Out:
# [*********************100%***********************]  7 of 7 completed
# (1260, 42)

# %%
data.head(10)
# Out:
#             Adj Close              ...      Volume
#                  AAPL        AMZN  ...        MSFT        TSLA
# Date                               ...
# 2016-02-16        NaN         NaN  ...         NaN         NaN
# 2016-02-17  22.815565  534.099976  ...  40789000.0  29126000.0
# 2016-02-18  22.383070  525.000000  ...  27176000.0  19438000.0
# 2016-02-19  22.331917  534.900024  ...  33559100.0  14797000.0
# 2016-02-22  22.527231  559.500000  ...  25008300.0  25300500.0
# 2016-02-23  22.018002  552.940002  ...  28895300.0  29922000.0
# 2016-02-24  22.345863  554.039978  ...  33014500.0  26978000.0
# 2016-02-25  22.499331  555.150024  ...  26939500.0  28753500.0
# 2016-02-26  22.534208  555.229980  ...  35975900.0  30325500.0
# 2016-02-29  22.483057  552.520020  ...  31654000.0  22495000.0
#
# [10 rows x 42 columns]

# %%
data.to_csv("yfinance.csv")

# %%
data["Adj Close"]["AAPL"]
# Out:
# Date
# 2016-02-16           NaN
# 2016-02-17     22.815565
# 2016-02-18     22.383070
# 2016-02-19     22.331917
# 2016-02-22     22.527231
#                  ...
# 2021-02-09    136.009995
# 2021-02-10    135.389999
# 2021-02-11    135.130005
# 2021-02-12    135.369995
# 2021-02-16    133.190002
# Name: AAPL, Length: 1260, dtype: float64
